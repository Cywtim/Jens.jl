# %%
# including packages
using LazyGrids, PyPlot, BenchmarkTools
using PSFModels, ImageFiltering
using PyPlot
include("LensBase.jl")
include("LensUtils.jl")
include("LensFITS.jl")
include("LensGenerator.jl")
# Out:
# WARNING: Method definition (::LensGenerator.var"#LensInstance#11"{var"#LensInstance#9"})() in module LensGenerator at /home/cyan/Documents/GitHub/Jens/LensGenerator.jl:83 overwritten at /home/cyan/Documents/GitHub/Jens/LensGenerator.jl:93.
# WARNING: Method definition kwcall(NamedTuple{names, T} where T<:Tuple where names, LensGenerator.var"#LensInstance#11"{var"#LensInstance#9"} where var"#LensInstance#9") in module LensGenerator at /home/cyan/Documents/GitHub/Jens/LensGenerator.jl:83 overwritten at /home/cyan/Documents/GitHub/Jens/LensGenerator.jl:93.
# Main.LensGenerator

# %% [markdown]
# # load model
