# %%
# adding the Path
# push!(LOAD_PATH) removed — use `using Jens` instead
#dirname(Pkg.project().path)
# including packages
using LazyGrids, PyPlot, BenchmarkTools
using PSFModels, ImageFiltering
using CairoMakie
include("../src/core/LensBase.jl")
include("../src/core/LensUtils.jl")
include("../src/io/LensFITS.jl")
include("../src/models/lens/NIE.jl")
include("../src/models/lens/SIS.jl")
include("../src/models/light/GaussianLight.jl")
# Out:
# Main.GaussianLight
