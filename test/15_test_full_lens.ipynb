# %%
using Jens, Cosmology, Statistics
using Jens: JFloat
# Out:
# [ Info: Precompiling Jens [51b7c8bc-8c55-4cde-95cb-80ce6c4547ac](cache misses: include_dependency fsize change (2), mismatched flags (7))
# [ Info: Precompiling Jens [51b7c8bc-8c55-4cde-95cb-80ce6c4547ac] (cache misses: include_dependency fsize change (4), mismatched flags (14))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up

# %%
cosmo = Cosmology.FlatLCDM(0.6736, 0.3153, 0.0, 0.0)
grid  = LensGenerator.GenGrid(pix_n=128, pix_size=Float32(0.05))
psf   = LensPSF.GaussianPSF(fwhm=0.10)

# True parameters
θ_E_true   = 1.15
e1_true    = 0.12
e2_true    = -0.04
amp_src    = 0.35
R_src      = 0.18
n_src      = 2.5
amp_lens   = 0.80 
R_lens     = 0.45
n_lens     = 4.0
e1_lens    = 0.10
e2_lens    = 0.03
flux_agn   = 25.0
z_lens     = 0.45
z_source   = 1.69

# Noise parameters
σ_gauss    = 0.005      # read noise [e-/s]
exp_time   = 5000.0     # exposure time [s]
# Out:
# 5000.0
